# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import matplotlib.pyplot as plt


from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
data_dir = pathlib.Path(data_dir)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 3s 0us/step
# 228827136/228813984 [==============================] - 3s 0us/step

# %%
roses = list(data_dir.glob('roses/*'))
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332 at 0x7FBC6B733CD0>

# %%
input_shape = (224,224)
batch_size = 32

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=input_shape,
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=input_shape,
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(2):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
image1,label1 = next(iter(train_ds))

# %%
first_image = image1[0]

# %%
print(keras.backend.max(first_image))
print(keras.backend.min(first_image))
# Out:
# tf.Tensor(255.0, shape=(), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)

# %%
normalize_ds = train_ds.map(lambda x,y : (x / 255.0, y))

# %%
image1,label1 = next(iter(normalize_ds))

# %%
first_image = image1[0]

# %%
print(keras.backend.max(first_image))
print(keras.backend.min(first_image))
# Out:
# tf.Tensor(0.97636074, shape=(), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)

# %%
num_classes = 5
input_shape = (224,224,3)

model = Sequential([
  layers.Rescaling(1./255, input_shape=input_shape),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes,activation='softmax')
])

# %%
model.compile(optimizer='Adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 128)               6422656
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 6,446,885
# Trainable params: 6,446,885
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 92/92 [==============================] - 41s 109ms/step - loss: 1.3524 - acc: 0.4356 - val_loss: 1.0957 - val_acc: 0.5627
# Epoch 2/10
# 92/92 [==============================] - 10s 100ms/step - loss: 0.9725 - acc: 0.6206 - val_loss: 0.9575 - val_acc: 0.6144
# Epoch 3/10
# 92/92 [==============================] - 10s 100ms/step - loss: 0.7749 - acc: 0.7132 - val_loss: 0.9452 - val_acc: 0.6362
# Epoch 4/10
# 92/92 [==============================] - 10s 100ms/step - loss: 0.5443 - acc: 0.8096 - val_loss: 1.2347 - val_acc: 0.5804
# Epoch 5/10
# 92/92 [==============================] - 10s 101ms/step - loss: 0.2873 - acc: 0.9040 - val_loss: 1.3137 - val_acc: 0.6158
# Epoch 6/10
# 92/92 [==============================] - 10s 102ms/step - loss: 0.1560 - acc: 0.9516 - val_loss: 1.5658 - val_acc: 0.6253
# Epoch 7/10
# 92/92 [==============================] - 10s 100ms/step - loss: 0.0898 - acc: 0.9707 - val_loss: 1.8515 - val_acc: 0.5845
# Epoch 8/10
# 92/92 [==============================] - 10s 101ms/step - loss: 0.0860 - acc: 0.9765 - val_loss: 1.6099 - val_acc: 0.6417
# Epoch 9/10
# 92/92 [==============================] - 10s 100ms/step - loss: 0.0578 - acc: 0.9854 - val_loss: 1.8173 - val_acc: 0.6253
# Epoch 10/10
# 92/92 [==============================] - 10s 101ms/step - loss: 0.0629 - acc: 0.9874 - val_loss: 1.7155 - val_acc: 0.6213

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=input_shape),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(2):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """

# %%
model = Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=input_shape),
  layers.experimental.preprocessing.RandomRotation(0.1),
  layers.experimental.preprocessing.RandomZoom(0.1),  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip_1 (RandomFlip)  (None, 224, 224, 3)       0
#
#  random_rotation_1 (RandomRo  (None, 224, 224, 3)      0
#  tation)
#
#  random_zoom_1 (RandomZoom)  (None, 224, 224, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 224, 224, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 112, 112, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 28, 28, 64)        0
#
#  flatten_1 (Flatten)         (None, 50176)             0
#
#  dense_2 (Dense)             (None, 128)               6422656
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 6,446,885
# Trainable params: 6,446,885
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 92/92 [==============================] - 11s 107ms/step - loss: 1.3865 - accuracy: 0.4077 - val_loss: 1.1851 - val_accuracy: 0.5204
# Epoch 2/15
# 92/92 [==============================] - 10s 104ms/step - loss: 1.0833 - accuracy: 0.5528 - val_loss: 1.0339 - val_accuracy: 0.5736
# Epoch 3/15
# 92/92 [==============================] - 10s 105ms/step - loss: 1.0035 - accuracy: 0.6114 - val_loss: 0.9138 - val_accuracy: 0.6390
# Epoch 4/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.8956 - accuracy: 0.6461 - val_loss: 0.8955 - val_accuracy: 0.6499
# Epoch 5/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.8623 - accuracy: 0.6683 - val_loss: 1.0233 - val_accuracy: 0.6308
# Epoch 6/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.8089 - accuracy: 0.6965 - val_loss: 0.8590 - val_accuracy: 0.6907
# Epoch 7/15
# 92/92 [==============================] - 10s 105ms/step - loss: 0.7708 - accuracy: 0.7050 - val_loss: 0.8127 - val_accuracy: 0.6975
# Epoch 8/15
# 92/92 [==============================] - 10s 105ms/step - loss: 0.7617 - accuracy: 0.7040 - val_loss: 0.8015 - val_accuracy: 0.6785
# Epoch 9/15
# 92/92 [==============================] - 10s 105ms/step - loss: 0.6942 - accuracy: 0.7343 - val_loss: 0.7570 - val_accuracy: 0.7016
# Epoch 10/15
# 92/92 [==============================] - 10s 105ms/step - loss: 0.6869 - accuracy: 0.7398 - val_loss: 0.7446 - val_accuracy: 0.7125
# Epoch 11/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.6528 - accuracy: 0.7452 - val_loss: 0.7108 - val_accuracy: 0.7302
# Epoch 12/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.6221 - accuracy: 0.7561 - val_loss: 0.7168 - val_accuracy: 0.7193
# Epoch 13/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.6114 - accuracy: 0.7718 - val_loss: 0.7820 - val_accuracy: 0.7084
# Epoch 14/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.5756 - accuracy: 0.7820 - val_loss: 0.7063 - val_accuracy: 0.7275
# Epoch 15/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.5584 - accuracy: 0.7875 - val_loss: 0.6776 - val_accuracy: 0.7575

# %%
model = Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=input_shape),
  layers.experimental.preprocessing.RandomRotation(0.1),
  layers.experimental.preprocessing.RandomZoom(0.1),  layers.experimental.preprocessing.Rescaling(1./255),
  
  # 2 Conv
  layers.Conv2D(64, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(64, 3, padding = 'same',  activation = 'relu'),
  # 1 MaxPooling
  layers.MaxPooling2D(),
  # 2 Conv
  layers.Conv2D(128, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(128, 3, padding = 'same',  activation = 'relu'),
  # 1 MaxPooling
  layers.MaxPooling2D(),
  # 3 Conv
  layers.Conv2D(256, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(256, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(256, 3, padding = 'same',  activation = 'relu'),
  # 1 MaxPooling
  layers.MaxPooling2D(),
  # 3 Conv
  layers.Conv2D(512, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(512, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(512, 3, padding = 'same',  activation = 'relu'),
  # 1 MaxPooling
  layers.MaxPooling2D(),
  # 3 Conv
  layers.Conv2D(512, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(512, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(512, 3, padding = 'same',  activation = 'relu'),
  # 1 MaxPooling
  layers.MaxPooling2D(),
  # Dropout
  layers.Dropout(0.5),
  # Flatten
  layers.Flatten(),
  # 3 FC
  layers.Dense(4096, activation = 'relu'),
  layers.Dense(4096, activation = 'relu'),
  layers.Dense(1000, activation = 'relu'),
  layers.Dense(num_classes, activation = 'softmax'),
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip_7 (RandomFlip)  (None, 224, 224, 3)       0
#
#  random_rotation_7 (RandomRo  (None, 224, 224, 3)      0
#  tation)
#
#  random_zoom_7 (RandomZoom)  (None, 224, 224, 3)       0
#
#  rescaling_7 (Rescaling)     (None, 224, 224, 3)       0
#
#  conv2d_58 (Conv2D)          (None, 224, 224, 64)      1792
#
#  conv2d_59 (Conv2D)          (None, 224, 224, 64)      36928
#
#  max_pooling2d_26 (MaxPoolin  (None, 112, 112, 64)     0
#  g2D)
#
#  conv2d_60 (Conv2D)          (None, 112, 112, 128)     73856
#
#  conv2d_61 (Conv2D)          (None, 112, 112, 128)     147584
#
#  max_pooling2d_27 (MaxPoolin  (None, 56, 56, 128)      0
#  g2D)
#
#  conv2d_62 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_63 (Conv2D)          (None, 56, 56, 256)       590080
#
#  conv2d_64 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_28 (MaxPoolin  (None, 28, 28, 256)      0
#  g2D)
#
#  conv2d_65 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  conv2d_66 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  conv2d_67 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  max_pooling2d_29 (MaxPoolin  (None, 14, 14, 512)      0
#  g2D)
#
#  conv2d_68 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_69 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_70 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_30 (MaxPoolin  (None, 7, 7, 512)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 7, 7, 512)         0
#
#  flatten_6 (Flatten)         (None, 25088)             0
#
#  dense_20 (Dense)            (None, 4096)              102764544
#
#  dense_21 (Dense)            (None, 4096)              16781312
#
#  dense_22 (Dense)            (None, 1000)              4097000
#
#  dense_23 (Dense)            (None, 5)                 5005
#
# =================================================================
# Total params: 138,362,549
# Trainable params: 138,362,549
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 92/92 [==============================] - 91s 967ms/step - loss: 1.6513 - accuracy: 0.2381 - val_loss: 1.6042 - val_accuracy: 0.2398
# Epoch 2/15
# 92/92 [==============================] - 89s 961ms/step - loss: 1.6021 - accuracy: 0.2459 - val_loss: 1.6030 - val_accuracy: 0.2398
# Epoch 3/15
# 92/92 [==============================] - 88s 953ms/step - loss: 1.6016 - accuracy: 0.2459 - val_loss: 1.6019 - val_accuracy: 0.2398
# Epoch 4/15
# 92/92 [==============================] - 88s 954ms/step - loss: 1.6010 - accuracy: 0.2459 - val_loss: 1.6031 - val_accuracy: 0.2398
# Epoch 5/15
# 92/92 [==============================] - 88s 954ms/step - loss: 1.6020 - accuracy: 0.2459 - val_loss: 1.6025 - val_accuracy: 0.2398
# Epoch 6/15
# 92/92 [==============================] - 88s 954ms/step - loss: 1.6011 - accuracy: 0.2459 - val_loss: 1.6025 - val_accuracy: 0.2398
# Epoch 7/15
# 92/92 [==============================] - 88s 955ms/step - loss: 1.6009 - accuracy: 0.2459 - val_loss: 1.6020 - val_accuracy: 0.2398
# Epoch 8/15
# 92/92 [==============================] - 89s 957ms/step - loss: 1.6008 - accuracy: 0.2459 - val_loss: 1.6023 - val_accuracy: 0.2398
# Epoch 9/15
# 92/92 [==============================] - 89s 960ms/step - loss: 1.6010 - accuracy: 0.2459 - val_loss: 1.6024 - val_accuracy: 0.2398
# Epoch 10/15
# 92/92 [==============================] - 89s 961ms/step - loss: 1.6009 - accuracy: 0.2459 - val_loss: 1.6023 - val_accuracy: 0.2398
# Epoch 11/15
# 92/92 [==============================] - 89s 962ms/step - loss: 1.6012 - accuracy: 0.2459 - val_loss: 1.6023 - val_accuracy: 0.2398
# Epoch 12/15
# 92/92 [==============================] - 89s 959ms/step - loss: 1.6008 - accuracy: 0.2459 - val_loss: 1.6019 - val_accuracy: 0.2398
# Epoch 13/15
# 92/92 [==============================] - 89s 959ms/step - loss: 1.6006 - accuracy: 0.2459 - val_loss: 1.6021 - val_accuracy: 0.2398
# Epoch 14/15
# 92/92 [==============================] - 89s 960ms/step - loss: 1.6005 - accuracy: 0.2459 - val_loss: 1.6018 - val_accuracy: 0.2398
# Epoch 15/15
# 92/92 [==============================] - 89s 960ms/step - loss: 1.6005 - accuracy: 0.2459 - val_loss: 1.6019 - val_accuracy: 0.2398

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
