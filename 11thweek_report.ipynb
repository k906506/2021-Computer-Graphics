# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import matplotlib.pyplot as plt


from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
data_dir = pathlib.Path(data_dir)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 3s 0us/step
# 228827136/228813984 [==============================] - 3s 0us/step

# %%
roses = list(data_dir.glob('roses/*'))
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x219 at 0x7F00C2519790>

# %%
input_shape = (224,224)
batch_size = 32

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=input_shape,
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=input_shape,
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(2):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
image1,label1 = next(iter(train_ds))

# %%
first_image = image1[0]

# %%
print(keras.backend.max(first_image))
print(keras.backend.min(first_image))
# Out:
# tf.Tensor(255.0, shape=(), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)

# %%
normalize_ds = train_ds.map(lambda x,y : (x / 255.0, y))

# %%
image1,label1 = next(iter(normalize_ds))

# %%
first_image = image1[0]

# %%
print(keras.backend.max(first_image))
print(keras.backend.min(first_image))
# Out:
# tf.Tensor(0.97636074, shape=(), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)

# %%
num_classes = 5
input_shape = (224,224,3)

model = Sequential([
  layers.Rescaling(1./255, input_shape=input_shape),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes,activation='softmax')
])

# %%
model.compile(optimizer='Adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 128)               6422656
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 6,446,885
# Trainable params: 6,446,885
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 92/92 [==============================] - 20s 108ms/step - loss: 1.4297 - acc: 0.4029 - val_loss: 1.0962 - val_acc: 0.5640
# Epoch 2/10
# 92/92 [==============================] - 10s 101ms/step - loss: 1.0164 - acc: 0.5903 - val_loss: 1.0244 - val_acc: 0.5749
# Epoch 3/10
# 92/92 [==============================] - 10s 100ms/step - loss: 0.8228 - acc: 0.6795 - val_loss: 1.0917 - val_acc: 0.5763
# Epoch 4/10
# 92/92 [==============================] - 10s 99ms/step - loss: 0.5665 - acc: 0.7807 - val_loss: 1.2317 - val_acc: 0.5790
# Epoch 5/10
# 92/92 [==============================] - 10s 100ms/step - loss: 0.3351 - acc: 0.8804 - val_loss: 1.3323 - val_acc: 0.6444
# Epoch 6/10
# 92/92 [==============================] - 10s 100ms/step - loss: 0.1769 - acc: 0.9462 - val_loss: 1.5388 - val_acc: 0.6458
# Epoch 7/10
# 92/92 [==============================] - 10s 99ms/step - loss: 0.1059 - acc: 0.9683 - val_loss: 1.6358 - val_acc: 0.6308
# Epoch 8/10
# 92/92 [==============================] - 10s 100ms/step - loss: 0.0883 - acc: 0.9748 - val_loss: 1.8961 - val_acc: 0.6308
# Epoch 9/10
# 92/92 [==============================] - 10s 100ms/step - loss: 0.0687 - acc: 0.9772 - val_loss: 1.9866 - val_acc: 0.6417
# Epoch 10/10
# 92/92 [==============================] - 10s 100ms/step - loss: 0.0416 - acc: 0.9891 - val_loss: 1.9295 - val_acc: 0.6158

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=input_shape),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(2):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """

# %%
model = Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=input_shape),
  layers.experimental.preprocessing.RandomRotation(0.1),
  layers.experimental.preprocessing.RandomZoom(0.1),  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip_1 (RandomFlip)  (None, 224, 224, 3)       0
#
#  random_rotation_1 (RandomRo  (None, 224, 224, 3)      0
#  tation)
#
#  random_zoom_1 (RandomZoom)  (None, 224, 224, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 224, 224, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 112, 112, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 28, 28, 64)        0
#
#  flatten_1 (Flatten)         (None, 50176)             0
#
#  dense_2 (Dense)             (None, 128)               6422656
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 6,446,885
# Trainable params: 6,446,885
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 92/92 [==============================] - 11s 106ms/step - loss: 1.5326 - accuracy: 0.3651 - val_loss: 1.1960 - val_accuracy: 0.5218
# Epoch 2/15
# 92/92 [==============================] - 10s 104ms/step - loss: 1.1224 - accuracy: 0.5378 - val_loss: 0.9996 - val_accuracy: 0.6022
# Epoch 3/15
# 92/92 [==============================] - 10s 104ms/step - loss: 1.0005 - accuracy: 0.6090 - val_loss: 0.9882 - val_accuracy: 0.6185
# Epoch 4/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.9224 - accuracy: 0.6386 - val_loss: 0.9426 - val_accuracy: 0.6308
# Epoch 5/15
# 92/92 [==============================] - 10s 105ms/step - loss: 0.8615 - accuracy: 0.6591 - val_loss: 1.0660 - val_accuracy: 0.6213
# Epoch 6/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.8144 - accuracy: 0.6904 - val_loss: 0.8791 - val_accuracy: 0.6717
# Epoch 7/15
# 92/92 [==============================] - 10s 105ms/step - loss: 0.7779 - accuracy: 0.7023 - val_loss: 0.8702 - val_accuracy: 0.6989
# Epoch 8/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.7561 - accuracy: 0.7187 - val_loss: 0.7879 - val_accuracy: 0.7016
# Epoch 9/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.7032 - accuracy: 0.7377 - val_loss: 0.7504 - val_accuracy: 0.7125
# Epoch 10/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.6792 - accuracy: 0.7425 - val_loss: 0.7421 - val_accuracy: 0.7153
# Epoch 11/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.6620 - accuracy: 0.7486 - val_loss: 0.7741 - val_accuracy: 0.6826
# Epoch 12/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.6382 - accuracy: 0.7541 - val_loss: 0.6877 - val_accuracy: 0.7384
# Epoch 13/15
# 92/92 [==============================] - 10s 105ms/step - loss: 0.6067 - accuracy: 0.7704 - val_loss: 0.7273 - val_accuracy: 0.7057
# Epoch 14/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.5863 - accuracy: 0.7728 - val_loss: 0.6946 - val_accuracy: 0.7384
# Epoch 15/15
# 92/92 [==============================] - 10s 104ms/step - loss: 0.5718 - accuracy: 0.7854 - val_loss: 0.7083 - val_accuracy: 0.7275

# %%
model = Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=input_shape),
  layers.experimental.preprocessing.RandomRotation(0.1),
  layers.experimental.preprocessing.RandomZoom(0.1),  layers.experimental.preprocessing.Rescaling(1./255),
  
  # 2 Conv
  layers.Conv2D(64, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(64, 3, padding = 'same',  activation = 'relu'),
  # 1 MaxPooling
  layers.MaxPooling2D(),
  # 2 Conv
  layers.Conv2D(128, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(128, 3, padding = 'same',  activation = 'relu'),
  # 1 MaxPooling
  layers.MaxPooling2D(),
  # 3 Conv
  layers.Conv2D(256, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(256, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(256, 3, padding = 'same',  activation = 'relu'),
  # 1 MaxPooling
  layers.MaxPooling2D(),
  # 3 Conv
  layers.Conv2D(512, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(512, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(512, 3, padding = 'same',  activation = 'relu'),
  # 1 MaxPooling
  layers.MaxPooling2D(),
  # 3 Conv
  layers.Conv2D(512, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(512, 3, padding = 'same',  activation = 'relu'),
  layers.Conv2D(512, 3, padding = 'same',  activation = 'relu'),
  # 1 MaxPooling
  layers.MaxPooling2D(),
  # Dropout
  layers.Dropout(0.2),
  # Flatten
  layers.Flatten(),
  # 3 FC
  layers.Dense(4096, activation = 'relu'),
  layers.Dense(4096, activation = 'relu'),
  layers.Dense(1000, activation = 'relu'),
  layers.Dense(num_classes, activation = 'softmax'),
])

# %%
model.compile(optimizer=keras.optimizers.SGD(momentum=0.9),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip_2 (RandomFlip)  (None, 224, 224, 3)       0
#
#  random_rotation_2 (RandomRo  (None, 224, 224, 3)      0
#  tation)
#
#  random_zoom_2 (RandomZoom)  (None, 224, 224, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 224, 224, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 224, 224, 64)      1792
#
#  conv2d_7 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d_6 (MaxPooling  (None, 112, 112, 64)     0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_9 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_7 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_11 (Conv2D)          (None, 56, 56, 256)       590080
#
#  conv2d_12 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_8 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  max_pooling2d_9 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_10 (MaxPoolin  (None, 7, 7, 512)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 512)         0
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 4096)              102764544
#
#  dense_5 (Dense)             (None, 4096)              16781312
#
#  dense_6 (Dense)             (None, 1000)              4097000
#
#  dense_7 (Dense)             (None, 5)                 5005
#
# =================================================================
# Total params: 138,362,549
# Trainable params: 138,362,549
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 92/92 [==============================] - 127s 1s/step - loss: 1.6032 - accuracy: 0.2398 - val_loss: 1.6048 - val_accuracy: 0.2398
# Epoch 2/15
# 92/92 [==============================] - 88s 952ms/step - loss: 1.5945 - accuracy: 0.2524 - val_loss: 1.5803 - val_accuracy: 0.2425
# Epoch 3/15
# 92/92 [==============================] - 87s 945ms/step - loss: 1.5764 - accuracy: 0.2708 - val_loss: 1.5978 - val_accuracy: 0.2425
# Epoch 4/15
# 92/92 [==============================] - 87s 941ms/step - loss: 1.5604 - accuracy: 0.2817 - val_loss: 1.4649 - val_accuracy: 0.3379
# Epoch 5/15
# 92/92 [==============================] - 87s 945ms/step - loss: 1.4939 - accuracy: 0.3277 - val_loss: 1.4527 - val_accuracy: 0.3869
# Epoch 6/15
# 92/92 [==============================] - 87s 943ms/step - loss: 1.5061 - accuracy: 0.3147 - val_loss: 1.4710 - val_accuracy: 0.3460
# Epoch 7/15
# 92/92 [==============================] - 87s 945ms/step - loss: 1.4449 - accuracy: 0.3478 - val_loss: 1.4014 - val_accuracy: 0.3965
# Epoch 8/15
# 92/92 [==============================] - 87s 945ms/step - loss: 1.4110 - accuracy: 0.3879 - val_loss: 1.3616 - val_accuracy: 0.4128
# Epoch 9/15
# 92/92 [==============================] - 88s 946ms/step - loss: 1.3452 - accuracy: 0.4176 - val_loss: 1.2841 - val_accuracy: 0.4346
# Epoch 10/15
# 92/92 [==============================] - 87s 945ms/step - loss: 1.3151 - accuracy: 0.4424 - val_loss: 1.2775 - val_accuracy: 0.4796
# Epoch 11/15
# 92/92 [==============================] - 87s 946ms/step - loss: 1.2927 - accuracy: 0.4527 - val_loss: 1.2179 - val_accuracy: 0.4905
# Epoch 12/15
# 92/92 [==============================] - 87s 946ms/step - loss: 1.2623 - accuracy: 0.4850 - val_loss: 1.1928 - val_accuracy: 0.4891
# Epoch 13/15
# 92/92 [==============================] - 88s 947ms/step - loss: 1.2181 - accuracy: 0.4942 - val_loss: 1.1586 - val_accuracy: 0.5477
# Epoch 14/15
# 92/92 [==============================] - 87s 946ms/step - loss: 1.1638 - accuracy: 0.5242 - val_loss: 1.2657 - val_accuracy: 0.4074
# Epoch 15/15
# 92/92 [==============================] - 88s 947ms/step - loss: 1.1597 - accuracy: 0.5106 - val_loss: 1.1785 - val_accuracy: 0.4959

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
